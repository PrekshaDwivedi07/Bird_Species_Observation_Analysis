# %% [markdown]
# <a href="https://colab.research.google.com/github/PrekshaDwivedi07/Bird_Species_Observation_Analysis/blob/main/Bird_Species_Observation_EDA_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Exploratory Data Analysis of Bird Species Observation .

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Project Overview:
# This project centers around conducting Exploratory Data Analysis (EDA) on a bird species observation dataset, aiming to gain a comprehensive understanding of birdwatching trends, species diversity, and ecological patterns. The analysis highlights seasonal movements, regional diversity, and species-specific behavioral trends across observed records.
#
# Key Activities:
# Data Gathering and Preparation:
# The dataset included bird sighting records containing details such as species names, observation dates, locations, observer effort, and environmental context. Data preprocessing involved handling missing values, standardizing species names, formatting timestamps, and ensuring location consistency to enable accurate analysis.
#
# Visualization Techniques:
# A wide range of visual tools were applied—such as bar charts, time series plots, geographical maps, box plots, scatter plots, and heatmaps—to effectively explore and interpret species distribution, observation frequency, and seasonal variation.
#
# Findings and Patterns:
# The analysis led to several meaningful observations:
#
# A few species are observed significantly more often, indicating either abundance or ease of identification.
#
# Bird sightings peak during spring and autumn months, aligning with known migratory periods.
#
# Forests and wetlands report the highest species richness compared to urban areas.
#
# Rare species sightings are limited to specific regions, highlighting potential conservation hotspots.
#
# Observation activity rises during birdwatching events or citizen science initiatives, contributing to data volume and coverage.
#
# This EDA offers insightful perspectives on bird species behavior, geographical distribution, and seasonal patterns. These findings can aid ecologists, wildlife researchers, and policy-makers in supporting biodiversity, shaping conservation programs, and promoting environmental awareness. Future analysis could explore predictive modeling of migration or species presence based on habitat and climate variables.

# %% [markdown]
# # **GitHub Link -**
# https://github.com/PrekshaDwivedi07/Bird_Species_Observation_Analysis.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The project aims to analyze the distribution and diversity of bird species in two distinct ecosystems: forests and grasslands. By examining bird species observations across these habitats, the goal is to understand how environmental factors, such as vegetation type, climate, and terrain, influence bird populations and their behavior. The study will involve working on the provided observational data of bird species present in both ecosystems, identifying patterns of habitat preference, and assessing the impact of these habitats on bird diversity. The findings can provide valuable insights into habitat conservation, biodiversity management, and the effects of environmental changes on avian communities.

# %% [markdown]
# ## Business Objective

# %% [markdown]
# Wildlife Conservation: Inform decisions on protecting critical bird habitats and enhancing biodiversity conservation efforts.
#
# **Land Management**: Optimize land use and habitat restoration strategies by understanding the preferences of different bird species.
#
# **Eco-Tourism**: Identify bird-rich areas to develop bird-watching tourism, attracting eco-tourists and boosting local economies.
#
# **Sustainable Agriculture**: Support the development of agricultural practices that minimize the impact on bird populations in grasslands and forests.
#
# **Policy Support**: Provide data-driven insights to help environmental agencies create effective conservation policies and strategies for vulnerable bird species.
#
# **Biodiversity Monitoring**: Track the health and diversity of avian populations, aiding in the monitoring of ecosystem stability.

# %% [markdown]
# ## ***Data Wrangling***

# %%
#import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
file_path = "/content/Bird_Monitoring_Data_FOREST.XLSX"

# %%
file_path2 = "/content/Bird_Monitoring_Data_GRASSLAND.XLSX"

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

excel_data = pd.ExcelFile(file_path)

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

excel_data_grass= pd.ExcelFile(file_path2)

# %%
sheet_names = excel_data.sheet_names

# %%
sheet_names2 = excel_data_grass.sheet_names

# %%
sheets_dict = {sheet: excel_data.parse(sheet) for sheet in sheet_names}

# %%
sheets_dict_2= {sheet: excel_data_grass.parse(sheet) for sheet in sheet_names2}

# %%
combined_df = pd.concat(
    [df.assign(Sheet=sheet_name) for sheet_name, df in sheets_dict.items()],
    ignore_index=True)

# %%
combined_df2 = pd.concat(
    [df.assign(Sheet=sheet_name2) for sheet_name2, df in sheets_dict_2.items()],
    ignore_index=True)

# %%
combined_df
# Out:
#      Admin_Unit_Code Sub_Unit_Code Site_Name  Plot_Name Location_Type    Year  \
# 0               ANTI           NaN    ANTI 1  ANTI-0036        Forest  2018.0
# 1               ANTI           NaN    ANTI 1  ANTI-0036        Forest  2018.0
# 2               ANTI           NaN    ANTI 1  ANTI-0036        Forest  2018.0
# 3               ANTI           NaN    ANTI 1  ANTI-0036        Forest  2018.0
# 4               ANTI           NaN    ANTI 1  ANTI-0036        Forest  2018.0
# ...              ...           ...       ...        ...           ...     ...
# 9413             NaN           NaN       NaN        NaN           NaN     NaN
# 9414             NaN           NaN       NaN        NaN           NaN     NaN
# 9415             NaN           NaN       NaN        NaN           NaN     NaN
# 9416             NaN           NaN       NaN        NaN           NaN     NaN
# 9417             NaN           NaN       NaN        NaN           NaN     NaN
#
# ...

# %%
combined_df2
# Out:
#      Admin_Unit_Code  Sub_Unit_Code  Plot_Name Location_Type  Year       Date  \
# 0               ANTI            NaN  ANTI-0054     Grassland  2018 2018-05-22
# 1               ANTI            NaN  ANTI-0054     Grassland  2018 2018-05-22
# 2               ANTI            NaN  ANTI-0054     Grassland  2018 2018-05-22
# 3               ANTI            NaN  ANTI-0054     Grassland  2018 2018-05-22
# 4               ANTI            NaN  ANTI-0054     Grassland  2018 2018-05-22
# ...              ...            ...        ...           ...   ...        ...
# 8526            MONO            NaN  MONO-0089     Grassland  2018 2018-05-10
# 8527            MONO            NaN  MONO-0089     Grassland  2018 2018-05-10
# 8528            MONO            NaN  MONO-0089     Grassland  2018 2018-05-10
# 8529            MONO            NaN  MONO-0089     Grassland  2018 2018-05-10
# 8530            MONO            NaN  MONO-0089     Grassland  2018 2018-05-10
#
# ...

# %%
combined_df = combined_df.drop(columns=['Sheet'])

# %%
combined_df2 = combined_df2.drop(columns=['Sheet'])

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9418 entries, 0 to 9417
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Admin_Unit_Code              8546 non-null   object
#  1   Sub_Unit_Code                722 non-null    object
#  2   Site_Name                    8546 non-null   object
#  3   Plot_Name                    8546 non-null   object
#  4   Location_Type                8546 non-null   object
#  5   Year                         8546 non-null   float64
#  6   Date                         8546 non-null   datetime64[ns]
#  7   Start_Time                   8546 non-null   object
#  8   End_Time                     8546 non-null   object
#  9   Observer                     8546 non-null   object
#  10  Visit                        8546 non-null   float64
#  11  Interval_Length              8546 non-null   object
# ...

# %%
combined_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8531 entries, 0 to 8530
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Admin_Unit_Code              8531 non-null   object
#  1   Sub_Unit_Code                0 non-null      float64
#  2   Plot_Name                    8531 non-null   object
#  3   Location_Type                8531 non-null   object
#  4   Year                         8531 non-null   int64
#  5   Date                         8531 non-null   datetime64[ns]
#  6   Start_Time                   8531 non-null   object
#  7   End_Time                     8531 non-null   object
#  8   Observer                     8531 non-null   object
#  9   Visit                        8531 non-null   int64
#  10  Interval_Length              8531 non-null   object
#  11  ID_Method                    8530 non-null   object
# ...

# %%
combined_df.shape
# Out:
# (9418, 29)

# %%
combined_df2.shape
# Out:
# (8531, 29)

# %% [markdown]
# ### **Dataset Information -**

# %% [markdown]
# ##**Dataset Overview**
# This Combined_df comprises 9,418 entries related to bird species observations across various locations and dates. It contains detailed metadata about each observation event, including geographical units, plot information, environmental conditions, observer details, and bird species identified. The data appears to be designed for ecological or ornithological studies—particularly useful for analyzing species behavior, migration patterns, and habitat preferences.
#
# And
#
# This Combined_df2 contains 8,531 records of bird species observations across various plots and dates. Each entry represents a single observation event, with detailed information on location, timing, observer details, species identification, and environmental conditions. The dataset is suitable for ecological and ornithological analyses, including studying species distribution, seasonal trends, and habitat preferences.
#
# ##**For Combined_df**
# ##**Column Descriptions** -
#
# The dataset contains observational data for bird species recorded across multiple forest sites. It includes detailed columns describing location, observation methods, bird species, and environmental conditions.
#
#
# Admin_Unit_Code: The code for the administrative unit (e.g., "ANTI") where the observation was conducted.
#
# Sub_Unit_Code: The sub-unit within the administrative unit for further classification.
#
# Site_Name: The name of the specific observation site within the unit.
#
# Plot_Name: A unique identifier for the specific plot where observations were recorded.
#
# Location_Type: The habitat type of the observation area (e.g., "Forest").
#
# Year: The year in which the observation took place.
# Date: The exact date of the observation.
#
# Start_Time: The start time of the observation session.
# End_Time: The end time of the observation session.
#
# Observer: The individual who conducted the observation.
#
# Visit: The count of visits made to the same observation site or plot.
#
# Interval_Length: The duration of the observation interval (e.g., "0-2.5 min").
#
# ID_Method: The method used to identify the species (e.g., "Singing," "Calling," "Visualization").
#
# Distance: The distance of the observed species from the observer (e.g., "<= 50 Meters").
#
# Flyover_Observed: Indicates whether the bird was observed flying overhead (TRUE/FALSE).
#
# Sex: The sex of the observed bird (e.g., Male, Female, Undetermined).
#
# Common_Name: The common name of the observed bird species (e.g., "Eastern Towhee").
#
# Scientific_Name: The scientific name of the observed bird species (e.g., Pipilo erythrophthalmus).
#
# AcceptedTSN: The Taxonomic Serial Number for the observed species.
#
# NPSTaxonCode: A unique code assigned to the taxon of the species.
#
# AOU_Code: The American Ornithological Union code for the species.
#
# PIF_Watchlist_Status: Indicates whether the species is on the Partners in Flight Watchlist (e.g., "TRUE" for at-risk species).
#
# Regional_Stewardship_Status: Denotes the conservation priority within the region (TRUE/FALSE).
#
# Temperature: The temperature recorded at the time of observation (in degrees).
#
# Humidity: The humidity percentage recorded at the time of observation.
#
# Sky: The sky condition during the observation (e.g., "Cloudy/Overcast").
#
# Wind: The wind condition (e.g., "Calm (< 1 mph) smoke rises vertically").
#
# Disturbance: Notes any disturbances that could affect the observation (e.g., "No effect on count").
#
# Initial_Three_Min_Cnt: The count of the species observed in the first three minutes of the session.
#
#
#
#
# ##**And For Combined_df2** -
#
# ##**Column Descriptions** -
#
# Admin_Unit_Code: Code of the administrative unit (e.g., "ANTI") where the observation occurred.
#
# Sub_Unit_Code: Sub-unit within the administrative unit (note: no values present in this dataset).
#
# Plot_Name: Unique identifier for the specific plot of observation.
#
# Location_Type: Habitat type of the observation area (e.g., "Forest").
#
# Year: Year in which the observation was made.
#
# Date: Exact date of the observation.
#
# Start_Time: Start time of the observation session.
#
# End_Time: End time of the observation session.
#
# Observer: Name/identifier of the observer.
#
# Visit: Visit number for that site/plot.
#
# Interval_Length: Duration of the observation interval (e.g., "0-2.5 min").
#
# ID_Method: Method used to identify the species (e.g., "Singing," "Calling"). (1 missing value)
#
# Distance: Estimated distance of the observed bird from the observer (e.g., "<= 50 Meters"). (1,394 missing values)
#
# Flyover_Observed: Whether the bird was seen flying overhead (TRUE/FALSE).
#
# Sex: Sex of the observed bird (Male, Female, or Unknown).
#
# Common_Name: Common name of the species (e.g., "Eastern Towhee").
#
# Scientific_Name: Scientific name of the species (e.g., Pipilo erythrophthalmus).
#
# AcceptedTSN: Taxonomic Serial Number for the observed species. (24 missing values)
#
# TaxonCode: Code assigned to the species. (2 missing values)
#
# AOU_Code: American Ornithological Union code for the species.
#
# PIF_Watchlist_Status: TRUE if the species is on the Partners in Flight Watchlist.
#
# Regional_Stewardship_Status: TRUE if the species has a high conservation priority in the region.
#
# Temperature: Temperature (°C) recorded during the observation.
#
# Humidity: Relative humidity (%) recorded during the observation.
#
# Sky: Sky condition during the observation (e.g., "Cloudy").
#
# Wind: Wind condition (e.g., "Calm (<1 mph)").
#
# Disturbance: Any disturbance noted (e.g., "No effect on count").
#
# Previously_Obs: TRUE if the species was previously observed at the site.
#
# Initial_Three_Min_Cnt: TRUE if the species was counted within the first 3 minutes of the session.

# %% [markdown]
# ###**Data Vizualization**

# %% [markdown]
# Data visualization is the graphical representation of information and data. By using visual elements like charts, graphs, and maps, data visualization tools provide an accessible way to see and understand trends, outliers, and patterns in data

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### BARPLOT / COUNTPLOT

# %% [markdown]
# A bar plot is a type of chart that presents categorical data with rectangular bars with heights or lengths proportional to the values that they represent.

# %% [markdown]
# ### CountPlot of Bird Species(Forest)-

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data = combined_df, x = 'Common_Name', order=combined_df['Common_Name'].value_counts().index[:10])
plt.title('Count of Bird Species (Forest)\n', color = 'red')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##Insight -

# %% [markdown]
# The forest dataset shows that Red-eyed Vireo is the most frequently observed bird species, followed closely by Carolina Wren and Northern Cardinal.

# %% [markdown]
# ### CountPlot of Bird Species(Grassland)-

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data = combined_df2, x = 'Common_Name', order=combined_df2['Common_Name'].value_counts().index[:10])
plt.title('Count of Bird Species (Grassland)\n', color = 'red')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# In the grassland dataset, Northern Cardinal is the most frequently observed species, followed by European Starling and Field Sparrow.

# %% [markdown]
# ### BarPlot of Regional_stewardship_status (Forest)-

# %%
a = combined_df.Regional_Stewardship_Status .value_counts()
a
# Out:
# Regional_Stewardship_Status
# 0.0    6101
# 1.0    2445
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.barplot(x = a.index , y = a.values , width = 0.5 , color = 'skyblue' , edgecolor = 'black')
plt.title('Barplot of Regional_Stewardship_Status(Forest)\n', color = 'black')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# In the forest dataset, the majority of bird observations are not linked to regional stewardship priority species, with only a small fraction marked as True

# %% [markdown]
# ### BarPlot of Regional_stewardship_status (Grassland) -

# %%
b = combined_df2.Regional_Stewardship_Status .value_counts()
b
# Out:
# Regional_Stewardship_Status
# False    6991
# True     1540
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.barplot(x = b.index , y = b.values , width = 0.5 , color = 'skyblue' , edgecolor = 'black')
plt.title('Barplot of Regional_Stewardship_Status(Grassland)\n', color = 'black')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# The grassland dataset shows the same trend as the forest dataset — most bird observations are not associated with regional stewardship priority species, with only a smaller proportion marked as True.

# %% [markdown]
# ### BarPlot of Flyover_observed (Forest)-

# %%
c = combined_df.Flyover_Observed.value_counts()
c
# Out:
# Flyover_Observed
# 0.0    8454
# 1.0      92
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.barplot(x = c.index , y = c.values , width = 0.5 , color = 'skyblue' , edgecolor = 'black')
plt.title('Barplot of Flyover_Observed(Forest)\n', color = 'black')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# In the forest dataset, flyover observations are extremely rare compared to non-flyover observations — the vast majority of sightings are from birds that were not just flying overhead.

# %% [markdown]
# ### BarPlot of Flyover_observed (Grassland)-

# %%
c2 = combined_df2.Flyover_Observed.value_counts()
c2
# Out:
# Flyover_Observed
# False    7137
# True     1394
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.barplot(x = c2.index , y = c2.values , width = 0.5 , color = 'skyblue' , edgecolor = 'black')
plt.title('Barplot of Flyover_Observed(Grassland)\n', color = 'black')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# In the grassland dataset, most bird sightings are not flyover observations, though the proportion of flyovers is noticeably higher than in the forest dataset.

# %% [markdown]
# ### BarPlot of Visit (Forest)-

# %%
d= combined_df.Visit.value_counts()
d
# Out:
# Visit
# 1.0    4382
# 2.0    4164
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.barplot(x = d.index , y = d.values , width = 0.5 , color = 'skyblue' , edgecolor = 'black')
plt.title('Barplot of Visi(Forest)\n', color = 'black')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# In the forest dataset, the number of observations during Visit 1 and Visit 2 is quite similar, with Visit 1 having a slightly higher count.
# This suggests a relatively balanced sampling effort across visits in forest habitats.

# %% [markdown]
# ### BarPlot of Visit (Grassland)-

# %%
d2= combined_df2.Visit.value_counts()
d2
# Out:
# Visit
# 1    3206
# 3    2688
# 2    2637
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.barplot(x = d2.index , y = d2.values , width = 0.5 , color = 'skyblue' , edgecolor = 'black')
plt.title('Barplot of Visi(Grassland)\n', color = 'black')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# In the grassland dataset, Visit 1 has the highest number of observations, followed by Visit 3 and Visit 2 (which has the lowest).
# This suggests a slightly uneven sampling effort across visits in grassland habitats, with a stronger emphasis during the first visit.

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ## LINE PLOT

# %% [markdown]
# Line Plot Connects data points with a line to show trends over time across continuous variable.

# %% [markdown]
# ### Line Plot of Sightings Vs Year(Grassland)

# %%
combined_df2['Date'] = pd.to_datetime(combined_df2['Date'])

combined_df2['Month'] = combined_df2['Date'].dt.month


def get_season(month):
    if 3 <= month <= 5:
        return 'Spring'
    elif 6 <= month <= 8:
        return 'Summer'
    elif 9 <= month <= 11:
        return 'Autumn'
    else:
        return 'Winter'

combined_df2['Season'] = combined_df2['Month'].apply(get_season)


sightings_by_season_year = combined_df2.groupby(['Year', 'Season']).size().reset_index(name='Sightings')

plt.figure(figsize=(12, 6))
sns.lineplot(data=sightings_by_season_year, x='Year', y='Sightings', hue='Season', marker='o')
plt.title('Grassland Bird Sightings by Season and Year')
plt.xlabel('Year')
plt.ylabel('Number of Sightings')
plt.xticks(sightings_by_season_year['Year'].unique())
plt.grid(True)
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# In 2018, there were significantly more grassland bird sightings in the summer than in the spring.

# %% [markdown]
# ### Line Plot of Sightings Vs Year(Forest)

# %%
combined_df['Date'] = pd.to_datetime(combined_df['Date'])


combined_df['Month'] = combined_df['Date'].dt.month

def get_season(month):
    if 3 <= month <= 5:
        return 'Spring'
    elif 6 <= month <= 8:
        return 'Summer'
    elif 9 <= month <= 11:
        return 'Autumn'
    else:
        return 'Winter'

combined_df['Season'] = combined_df['Month'].apply(get_season)


sightings_by_season_year2 = combined_df.groupby(['Year', 'Season']).size().reset_index(name='Sightings')

plt.figure(figsize=(12, 6))
sns.lineplot(data=sightings_by_season_year2, x='Year', y='Sightings', hue='Season', marker='o')
plt.title('forest Bird Sightings by Season and Year')
plt.xlabel('Year')
plt.ylabel('Number of Sightings')
plt.xticks(sightings_by_season_year2['Year'].unique())
plt.grid(True)
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# In 2018, there were significantly more forest bird sightings in the summer than in the spring.

# %% [markdown]
# ### BarPlot of Sightings by Months (Grassland)

# %%
monthly_avg = combined_df2.groupby(combined_df2['Date'].dt.month).size().reset_index(name='Sightings')
monthly_avg = monthly_avg.rename(columns={'Date': 'Month'})

plt.figure(figsize=(10, 5))
sns.barplot(data=monthly_avg, x='Month', y='Sightings', color='skyblue')
plt.title("Bird Sightings by Month (Grassland)", fontsize=14)
plt.ylabel("Number of Sightings")
plt.xlabel("Month")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# Bird sightings in grasslands were highest in May, with the count dropping in June before rising again in July. May had over 3,000 sightings, while June had the fewest.

# %% [markdown]
# ### BarPlot of Sightings by Months (Forest)

# %%
monthly_avg = combined_df.groupby(combined_df['Date'].dt.month).size().reset_index(name='Sightings')
monthly_avg = monthly_avg.rename(columns={'Date': 'Month'})

plt.figure(figsize=(10, 5))
sns.barplot(data=monthly_avg, x='Month', y='Sightings', color='skyblue')
plt.title("Bird Sightings by Month (Forest)", fontsize=14)
plt.ylabel("Number of Sightings")
plt.xlabel("Month")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# Bird sightings in forests were lowest in July and highest in June. June had approximately 4,000 sightings, which is almost double the number seen in July.

# %% [markdown]
# ### BarPlot of Sightings by Wind Condition (Forest)

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=combined_df, x='Wind', order=combined_df['Wind'].value_counts().index, color='skyblue')
plt.title("Sightings by Wind Condition(Forest)", fontsize=14)
plt.xlabel("Wind Condition")
plt.ylabel("Number of Sightings")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# The graph shows a clear relationship between wind conditions and forest bird sightings. The highest number of sightings occurred during light air movement (1-3 mph), followed closely by calm conditions (< 1 mph). Sightings dropped significantly during light breezes (4-7 mph) and were lowest during gentle breezes (8-12 mph).

# %% [markdown]
# ### BarPlot of Sightings by Wind Condition (Grassland)

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=combined_df2, x='Wind', order=combined_df2['Wind'].value_counts().index, color='skyblue')
plt.title("Sightings by Wind Condition(Grassland)", fontsize=14)
plt.xlabel("Wind Condition")
plt.ylabel("Number of Sightings")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# The most grassland bird sightings occurred during light air movement (1-3 mph), with over 4,000 sightings. As the wind speed increased, the number of sightings decreased significantly, with the lowest number occurring during a gentle breeze (8-12 mph).

# %% [markdown]
# ### BarPlot of Top 5 Plots by Number of Sightings(Forest)

# %%
plot_counts = combined_df['Plot_Name'].value_counts().head(5)

plt.figure(figsize=(12,6))
sns.barplot(x=plot_counts.values, y=plot_counts.index, palette="viridis")
plt.title("Top 5 Plots by Number of Sightings(Forest)", fontsize=14)
plt.xlabel("Number of Sightings")
plt.ylabel("Plot Name")
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# The graph displays the top five forest plots with the most bird sightings. The CHOH-0812 plot had the highest number of sightings, followed by NACE-0477 and CHOH-1081. The MONO-0074 plot had the lowest number of sightings among the top five.

# %% [markdown]
# ### BarPlot of Top 5 Plots by Number of Sightings(Grassland)

# %%
plot_counts = combined_df2['Plot_Name'].value_counts().head(5)

plt.figure(figsize=(12,6))
sns.barplot(x=plot_counts.values, y=plot_counts.index, palette="viridis")
plt.title("Top 5 Plots by Number of Sightings()", fontsize=14)
plt.xlabel("Number of Sightings")
plt.ylabel("Plot Name")
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# The bar chart shows the top 5 grassland plots with the most bird sightings. The MONO-0054 plot has the highest number of sightings, with over 200. The plots MONO-0094 and MANA-0076 have a similar number of sightings, around 120. The MONO-0050 plot has the fewest sightings among the top five.

# %% [markdown]
# ### CountPlot of Top 10 Species Sightings by Year (Forest)

# %%
top_10_species = combined_df['Common_Name'].value_counts().nlargest(10).index

filtered_df = combined_df[combined_df['Common_Name'].isin(top_10_species)]

plt.figure(figsize=(12, 6))
sns.countplot(data=filtered_df, x='Year', hue='Common_Name')
plt.title("Top 10 Species Sightings by Year (Forest)", fontsize=14)
plt.xlabel("Year")
plt.ylabel("Number of Sightings")
plt.xticks(rotation=45)
plt.legend(title="Species", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# The top 10 species sighted in the forest in 2018 were, in descending order: Red-eyed Vireo, Carolina Wren, Northern Cardinal, Eastern Tufted Titmous, Eastern Wood-Pewee, Red-bellied Woodpecker, Acadia Flycatcher, Ovenbird, American Robin, and Blue-gray Gnatcatcher.

# %% [markdown]
# ### CountPlot of Top 10 Species Sightings by Year (Grassland)

# %%
top_10_species = combined_df2['Common_Name'].value_counts().nlargest(10).index

filtered_df = combined_df2[combined_df2['Common_Name'].isin(top_10_species)]

plt.figure(figsize=(12, 6))
sns.countplot(data=filtered_df, x='Year', hue='Common_Name')
plt.title("Top 10 Species Sightings by Year (Grassland)", fontsize=14)
plt.xlabel("Year")
plt.ylabel("Number of Sightings")
plt.xticks(rotation=45)
plt.legend(title="Species", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# The chart shows the top 10 species sighted in grassland in 2018. The Northern Cardinal had the most sightings, followed by the European Starling and Field Sparrow. The Cedar Waxwing had the fewest sightings among the top 10 species.

# %% [markdown]
# ### CountPlot of Species Distribution by Location Type(forest)

# %%
top_10_species2 = combined_df['Common_Name'].value_counts().nlargest(10).index
filtered_df2 = combined_df[combined_df['Common_Name'].isin(top_10_species2)]
plt.figure(figsize=(10,6))
sns.countplot(data=filtered_df2, x='Location_Type', hue='Common_Name')
plt.title("Species Distribution by Location Type(forest)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# In the forest location type, the Red-eyed Vireo had the highest number of sightings, followed by the Carolina Wren and Northern Cardinal. The Blue-gray Gnatcatcher and American Robin had the lowest number of sightings among the species shown.

# %% [markdown]
# ### CountPlot of Species Distribution by Location Type (Grassland)

# %%
top_10_species3 = combined_df2['Common_Name'].value_counts().nlargest(10).index
filtered_df3 = combined_df2[combined_df2['Common_Name'].isin(top_10_species3)]
plt.figure(figsize=(10,6))
sns.countplot(data=filtered_df3, x='Location_Type', hue='Common_Name')
plt.title("Species Distribution by Location Type(grassland)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# The chart shows that in grassland locations, the Northern Cardinal had the highest number of sightings. The Field Sparrow and Indigo Bunting also had a high number of sightings, while the Cedar Waxwing had the lowest number of sightings among the species shown.

# %% [markdown]
# ### CountPlot of Activity Patterns: ID Method by Interval Length  (Forest)

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=combined_df, x='Interval_Length', hue='ID_Method', palette='pastel')
plt.title("Activity Patterns: ID Method by Interval Length(Forest)")
plt.xlabel("Interval Length")
plt.ylabel("Count")
plt.legend(title="ID Method", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# The chart shows that singing is the most common method of identifying birds in forests across all interval lengths, especially in the shortest interval of 0-2.5 minutes. As the interval length increases, the number of sightings identified by singing and calling decreases. Identification by visualization remains relatively consistent across all interval lengths.

# %% [markdown]
# ### CountPlot of Activity Patterns: ID Method by Interval Length  (Grassland)

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=combined_df2, x='Interval_Length', hue='ID_Method', palette='pastel')
plt.title("Activity Patterns: ID Method by Interval Length(Grassland)")
plt.xlabel("Interval Length")
plt.ylabel("Count")
plt.legend(title="ID Method", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# Based on the graph, bird sightings in grasslands were most often identified by singing during the shortest interval (0-2.5 min).
#
#  The number of sightings identified by singing decreases as the interval length increases.
#
#  Visualization is also a significant method of identification, especially in the 0-2.5 minute interval where it is almost as common as calling.
#
#  The number of birds identified by calling is consistently lower than the other two methods across all interval lengths.

# %% [markdown]
# ### BarPlot of Distribution of Bird Identification Methods(Forest)

# %%
id_method_counts = combined_df['ID_Method'].value_counts()

plt.figure(figsize=(8,6))
sns.barplot(x=id_method_counts.index, y=id_method_counts.values, palette="mako")
plt.title("Distribution of Bird Identification Methods(Forest)")
plt.xlabel("ID Method")
plt.ylabel("Number of Observations")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# In the forest, birds were most often identified by singing, with over 5,000 observations. Calling was the second most common identification method, while visualization was the least common.

# %% [markdown]
# ### BarPlot of Distribution of Bird Identification Methods(Gassland)

# %%
id_method_counts = combined_df2['ID_Method'].value_counts()

plt.figure(figsize=(8,6))
sns.barplot(x=id_method_counts.index, y=id_method_counts.values, palette="mako")
plt.title("Distribution of Bird Identification Methods(Grassland)")
plt.xlabel("ID Method")
plt.ylabel("Number of Observations")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# In grasslands, birds were most frequently identified by singing, with over 4,000 observations. Visualization was the second most common method, and calling was the least common method of identification.

# %% [markdown]
# ### SCATTER PLOT

# %% [markdown]
# A scatter plot is a type of data visualization that uses dots to represent the values of two numerical variables. Scatter plots are used to observe relationships between variables.

# %% [markdown]
# ### Scatter plot of Temperature vs. Humidity by Season(forest)

# %%
combined_df['Date'] = pd.to_datetime(combined_df['Date'])

combined_df['Month'] = combined_df['Date'].dt.month

def get_season(month):
    if 3 <= month <= 5:
        return 'Spring'
    elif 6 <= month <= 8:
        return 'Summer'
    elif 9 <= month <= 11:
        return 'Autumn'
    else:
        return 'Winter'

combined_df['Season'] = combined_df['Month'].apply(get_season)

plt.figure(figsize=(8,6))
sns.scatterplot(data=combined_df, x='Temperature', y='Humidity', hue='Season')
plt.title("Temperature vs. Humidity by Season(forest)")
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# The scatter plot shows that as temperature increases, humidity generally increases in the forest. Summer has the highest temperatures and a wide range of humidity, while spring has lower temperatures and also a high range of humidity. No data is shown for the winter season.

# %% [markdown]
# ### Scatter plot of Temperature vs. Humidity by Season (Grassland)

# %%
combined_df2['Date'] = pd.to_datetime(combined_df2['Date'])

combined_df2['Month'] = combined_df2['Date'].dt.month

def get_season(month):
    if 3 <= month <= 5:
        return 'Spring'
    elif 6 <= month <= 8:
        return 'Summer'
    elif 9 <= month <= 11:
        return 'Autumn'
    else:
        return 'Winter'

combined_df2['Season'] = combined_df2['Month'].apply(get_season)

plt.figure(figsize=(8,6))
sns.scatterplot(data=combined_df2, x='Temperature', y='Humidity', hue='Season')
plt.title("Temperature vs. Humidity by Season(Grassland)")
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# The scatter plot shows a general trend where humidity decreases as temperature increases in the grassland. Spring shows a wider spread of humidity at lower temperatures, while summer data points are more clustered at higher temperatures and lower humidity levels.

# %% [markdown]
# ## PIE CHART

# %% [markdown]
# Pie chart is used to visualize the proportions of different categories within a whole dataset. I's circular statistical graph, where each slice of the pie represents a category, and the size of the slice is proportional to the category's contribution to the overall data

# %% [markdown]
# ### Pie chart of Top 10 Species Distribution (forest)

# %%
species_counts = combined_df['Common_Name'].value_counts().head(10)
plt.figure(figsize=(6,6))
plt.pie(species_counts, labels=species_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Top 10 Species Distribution(forest)")
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# Based on the pie chart, the Red-eyed Vireo constitutes the largest percentage of sightings at 14.8%, making it the most sighted species in the forest. The Carolina Wren and Northern Cardinal are the next most sighted species, with 13.7% and 12.7% respectively. The least sighted species among the top 10 is the American Robin, accounting for 6.3% of the sightings.

# %% [markdown]
# ### Pie chart of Top 10 Species Distribution (Grassland)

# %%
species_counts = combined_df2['Common_Name'].value_counts().head(10)
plt.figure(figsize=(6,6))
plt.pie(species_counts, labels=species_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Top 10 Species Distribution(grassland)")
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# Based on the pie chart, the Northern Cardinal is the most sighted species in the grassland, accounting for 13.4% of the top 10 species. This is followed by the European Starling at 12.2% and the Field Sparrow at 12.0%. The least sighted species among the top 10 is the Cedar Waxwing at 7.1%.

# %% [markdown]
# ### Pie chart of Sightings by Sky Condition (Forest)

# %%
sky_counts = combined_df['Sky'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(sky_counts, labels=sky_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Sightings by Sky Condition(Forest)")
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# Based on the pie chart, the majority of forest bird sightings occurred under Partly Cloudy and Clear or Few Clouds conditions, which together account for nearly 70% of all sightings. Cloudy/Overcast conditions were responsible for 22% of sightings, while Mist/Drizzle and Fog accounted for a much smaller percentage of the total.

# %% [markdown]
# ### Pie chart of Sightings by Sky Condition (Grassland)

# %%
sky_counts = combined_df2['Sky'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(sky_counts, labels=sky_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Sightings by Sky Condition(Grassland)")
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# The vast majority of grassland bird sightings, over 80%, occurred on days that were either partly cloudy (48.7%) or had clear or few clouds (33.2%). Sightings were much less frequent during cloudy/overcast conditions (14.3%) and were very rare during mist, drizzle, or fog.

# %% [markdown]
# ### Pie chart of Sightings by Wind Condition(Forest)

# %%
wind_counts = combined_df['Wind'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(wind_counts, labels=wind_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Sightings by Wind Condition(Forest)")
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# In the forest, the vast majority of bird sightings occurred during **light air movement (1-3 mph)**, accounting for **48%** of observations, and **calm (< 1 mph)** conditions, accounting for **36.2%**. Sightings were significantly less frequent during **light breezes (4-7 mph)** and were very rare during **gentle breezes (8-12 mph)**.

# %% [markdown]
# ### Pie chart of Sightings by Wind Condition(Grassland)

# %%
wind_counts = combined_df['Wind'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(wind_counts, labels=wind_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Sightings by Wind Condition (Grassland)")
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# The chart shows that grassland bird sightings were most frequent during **light air movement (1-3 mph)**, which accounted for **48%** of observations, and **calm (< 1 mph)** conditions, with **36.2%**. The number of sightings decreased significantly as wind speed increased, with **light breezes (4-7 mph)** accounting for **14.2%** and **gentle breezes (8-12 mph)** for only **1.6%**.

# %% [markdown]
# ### Pie chart of Overall Sex Distribution(Forest)

# %%
sex_counts = combined_df['Sex'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(sex_counts, labels=sex_counts.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff','#ff9999','#99ff99'])
plt.title("Overall Sex Distribution(Forest)")
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# The vast majority of the bird sightings in the forest (98.2%) had an undetermined sex. Only a very small percentage of the sightings (1.8%) were confirmed as male.

# %% [markdown]
# ### Pie chart of Overall Sex Distribution (Grassland)

# %%
sex_counts = combined_df2['Sex'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(sex_counts, labels=sex_counts.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff','#ff9999','#99ff99'])
plt.title("Overall Sex Distribution(Grasland)")
plt.show()

# %% [markdown]
# ## Insight

# %% [markdown]
# The provided pie chart displays the overall sex distribution of bird sightings in grassland areas.
#
# Key Observations
# The majority of sightings, 59.9%, were of birds with undetermined sex.
#
# Male birds accounted for 38.4% of the total sightings.
#
# Female birds were the least-sighted group, making up only 1.7% of the observations.

# %% [markdown]
# ### Multivariable Analysis

# %% [markdown]
# ### PAIR PLOT

# %% [markdown]
# Pair plot visualizes the pairwise relationship between variables. It includes scatter plots for relationships and histogram or density plots for individual distributions.

# %% [markdown]
# ## PAIR PLOT of (Forest)

# %%
sns.pairplot(combined_df)
plt.show()

# %% [markdown]
# ## PAIR PLOT of (Grassland)

# %%
sns.pairplot(combined_df2)
plt.show()

# %% [markdown]
# ### HEATMAP

# %% [markdown]
# A heatmap uses color intensities to represent the strength of relationships correlation between numeric variables in a dataset.

# %% [markdown]
# ## Heatmap of Forest

# %%
plt.figure(figsize=(10,8))
num_col = combined_df.select_dtypes(include=np.number)
sns.heatmap(num_col.corr(), annot= True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ## Heatmap of Grassland

# %%
plt.figure(figsize=(10,8))
num_col = combined_df2.select_dtypes(include=np.number)
sns.heatmap(num_col.corr(), annot= True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ## Conclusion -

# %% [markdown]
# This EDA has revealed meaningful patterns in bird diversity, habitat preferences, and environmental influences on species activity.
#
# **Species Distribution & Habitat Patterns:** Grassland and forest units host distinct bird communities, with some species showing strong habitat specificity. Grasslands support open-area specialists, while forests exhibit higher diversity of canopy and understory species.
#
# **Temporal Trends:** Bird observations fluctuate across months and seasons, reflecting migration cycles, breeding periods, and seasonal habitat use. Certain time windows during the day consistently yield higher activity, suggesting optimal survey periods.
#
# **Environmental Influence:** Temperature, humidity, sky conditions, and wind all affect detection rates, with clear patterns linking favorable weather to higher bird activity. Disturbance levels, even slight, show measurable impacts on sightings for some species.
#
# **Behavioral Insights:** Distance data highlights which species tend to be observed near vs. far from observers, and flyover frequency varies by habitat, indicating different foraging and movement behaviors.
#
# **Observer & Visit Patterns:** Analysis of observer-specific records reveals potential bias in reporting, while repeated visits to the same plots capture changes in species richness and presence over time.
#
# **Conservation Priorities:** Several species flagged on the PIF Watchlist or with notable stewardship status occur in the dataset, underlining the importance of monitoring these populations in both habitat types.
#
#
# **Conclusion:** These findings provide valuable guidance for conservation planning, field survey optimization, and ecological monitoring. By integrating habitat-specific patterns, seasonal timing, and environmental drivers, stakeholders can design more targeted conservation actions, improve monitoring efficiency, and focus efforts on at-risk species.
